# %% [markdown]
# ## Data Loading and Summary

# %%
# !wget https://datasets.imdbws.com/title.basics.tsv.gz
# !wget https://datasets.imdbws.com/title.episode.tsv.gz
# !wget https://datasets.imdbws.com/title.ratings.tsv.gz
# Out:
# --2024-08-01 15:17:25--  https://datasets.imdbws.com/title.basics.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 52.85.132.80, 52.85.132.19, 52.85.132.66, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|52.85.132.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 192392247 (183M) [binary/octet-stream]
# Saving to: ‘title.basics.tsv.gz’
#
# title.basics.tsv.gz 100%[===================>] 183.48M  65.8MB/s    in 2.8s
#
# 2024-08-01 15:17:28 (65.8 MB/s) - ‘title.basics.tsv.gz’ saved [192392247/192392247]
#
# --2024-08-01 15:17:28--  https://datasets.imdbws.com/title.episode.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 52.85.132.80, 52.85.132.19, 52.85.132.66, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|52.85.132.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46158848 (44M) [binary/octet-stream]
# Saving to: ‘title.episode.tsv.gz’
#
# title.episode.tsv.g 100%[===================>]  44.02M  74.0MB/s    in 0.6s
#
# 2024-08-01 15:17:28 (74.0 MB/s) - ‘title.episode.tsv.gz’ saved [46158848/46158848]
#
# --2024-08-01 15:17:28--  https://datasets.imdbws.com/title.ratings.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 52.85.132.80, 52.85.132.19, 52.85.132.66, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|52.85.132.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7361875 (7.0M) [binary/octet-stream]
# Saving to: ‘title.ratings.tsv.gz’
#
# title.ratings.tsv.g 100%[===================>]   7.02M  --.-KB/s    in 0.1s
#
# 2024-08-01 15:17:29 (59.7 MB/s) - ‘title.ratings.tsv.gz’ saved [7361875/7361875]

# %%
# !gzip -d title.basics.tsv.gz
# !gzip -d title.episode.tsv.gz
# !gzip -d title.ratings.tsv.gz

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd

# %%
basics = pd.read_csv('title.basics.tsv', sep='\t', low_memory=False, na_values=['\\N'])
episode = pd.read_csv('title.episode.tsv', sep='\t', low_memory=False, na_values=['\\N'])
ratings = pd.read_csv('title.ratings.tsv', sep='\t', low_memory=False, na_values=['\\N'])

# %%
basics.head(3)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#    isAdult  startYear  endYear runtimeMinutes                      genres
# 0      0.0     1894.0      NaN              1           Documentary,Short
# 1      0.0     1892.0      NaN              5             Animation,Short
# 2      0.0     1892.0      NaN              5  Action,Adventure,Animation

# %%
episode.head(3)
# Out:
#       tconst parentTconst  seasonNumber  episodeNumber
# 0  tt0031458   tt32857063           NaN            NaN
# 1  tt0041951    tt0041038           1.0            9.0
# 2  tt0042816    tt0989125           1.0           17.0

# %%
ratings.head(3)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2064
# 1  tt0000002            5.6       279
# 2  tt0000003            6.5      2039

# %%
len(episode), len(basics), len(ratings)
# Out:
# (8400596, 10962448, 1464644)

# %% [markdown]
# ### Checking ID columns for uniqueness

# %%
basics['tconst'].is_unique, episode['tconst'].is_unique, ratings['tconst'].is_unique
# Out:
# (True, True, True)

# %%
# Check if columns 'tConst' and 'parentTconst' in episode have common values
len(set(episode['tconst']).intersection(set(episode['parentTconst'])))
# Out:
# 0

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Cleaning for `basics` Dataset

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
# Checking for null values
basics.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle            17
# originalTitle           17
# isAdult                  1
# startYear          1414482
# endYear           10835206
# runtimeMinutes     7546168
# genres              485607
# dtype: int64

# %%
# view all rows with null values of 'primaryTitle' or originalTitle'
basics[(basics['primaryTitle'].isna()) | (basics['originalTitle'].isna())]
# Out:
#               tconst  titleType primaryTitle originalTitle  isAdult  \
# 1253393   tt10516578      video          NaN           NaN      0.0
# 3430017   tt14510930  tvEpisode          NaN           NaN      0.0
# 4072843   tt15700278  tvEpisode          NaN           NaN      0.0
# 4553955   tt17042812      movie          NaN           NaN      0.0
# 5061656    tt1971246  tvEpisode          NaN           NaN      0.0
# 5257366    tt2067043  tvEpisode          NaN           NaN      0.0
# 5595729   tt21883066  tvEpisode          NaN           NaN      0.0
# 5865218    tt2305914  tvEpisode          NaN           NaN      0.0
# 5865225    tt2305918  tvEpisode          NaN           NaN      0.0
# 7535400   tt31462159  tvEpisode          NaN           NaN      0.0
# 7733365   tt32253130      short          NaN           NaN      0.0
# 8027467    tt3383210      short          NaN           NaN      0.0
# 9068391    tt5746000      short          NaN           NaN      0.0
# 9079970    tt5773048  tvEpisode          NaN           NaN      0.0
# 9080413    tt5774076      movie          NaN           NaN      0.0
# 10300001   tt8473688  tvEpisode          NaN           NaN      0.0
# 10331029   tt8541336  tvEpisode          NaN           NaN      0.0
#
#           startYear  endYear runtimeMinutes                     genres
# 1253393      2017.0      NaN            NaN                Music,Short
# 3430017         NaN      NaN            NaN                        NaN
# 4072843      2021.0      NaN            NaN                  Talk-Show
# 4553955      2010.0      NaN             87                   Thriller
# 5061656      2011.0      NaN            NaN                  Biography
# 5257366      1965.0      NaN            NaN                      Music
# 5595729      2022.0      NaN            NaN             News,Talk-Show
# 5865218         NaN      NaN            NaN           Comedy,Talk-Show
# 5865225         NaN      NaN            NaN           Comedy,Talk-Show
# 7535400      2024.0      NaN            NaN                      Drama
# 7733365         NaN      NaN            NaN            Biography,Short
# 8027467      2013.0      NaN             12  Documentary,History,Short
# 9068391      2016.0      NaN             12                      Short
# 9079970      2015.0      NaN            NaN                  Talk-Show
# 9080413      2015.0      NaN            NaN       Action,Drama,Mystery
# 10300001     1987.0      NaN            NaN                      Drama
# 10331029     2018.0      NaN             30         Reality-TV,Romance

# %% [markdown]
# 17 rows have missing values for both `primaryTitle` and `originalTitle` fields. We will remove these rows.

# %%
# Remove rows with null values in 'primaryTitle' and 'originalTitle'
basics = basics.dropna(subset=['primaryTitle', 'originalTitle'])

# %%
# View the only row with missing 'isAdult' value
pd.set_option('max_colwidth', None)
basics[basics['isAdult'].isna()]
# Out:
#              tconst  titleType  \
# 2989187  tt13704268  tvEpisode
#
#                                                                    primaryTitle  \
# 2989187  Bay of the Triffids/Doctor of Doom\tBay of the Triffids/Doctor of Doom
#
#         originalTitle  isAdult  startYear  endYear           runtimeMinutes  \
# 2989187             0      NaN        NaN      NaN  Animation,Comedy,Family
#
#         genres
# 2989187    NaN

# %% [markdown]
# In this case, the `\t` character was intepreted as literal string isntead of a `Tab` seperator.
#
# Instead of removing this row, we will fix it by reassigning the `primaryTitle`, `originalTitle`, and `isAdult` fields to their right values:
# - `primaryTitle`: Bay of the Triffids/Doctor of Doom
# - `originalTitle`: Bay of the Triffids/Doctor of Doom
# - isAdult: 0

# %%
# prompt: at row index 2989193, replace these columns primaryTitle, originalTitle, and isAdult with the values ['Bay of the Triffids/Doctor of Doom', 'Bay of the Triffids/Doctor of Doom', 0]

basics.loc[2989193, ['primaryTitle', 'originalTitle', 'isAdult']] = ['Bay of the Triffids/Doctor of Doom', 'Bay of the Triffids/Doctor of Doom', 0]
basics.loc[2989193]
# Out:
# tconst                                    tt13704278
# titleType                                  tvEpisode
# primaryTitle      Bay of the Triffids/Doctor of Doom
# originalTitle     Bay of the Triffids/Doctor of Doom
# isAdult                                          0.0
# startYear                                        NaN
# endYear                                          NaN
# runtimeMinutes                                   NaN
# genres                       Animation,Comedy,Family
# Name: 2989193, dtype: object

# %% [markdown]
# Next, we check if all values in the field `isAdult` is either 0 or 1

# %%
basics['isAdult'].value_counts()
# Out:
# isAdult
# 0.0       10609805
# 1.0         351998
# 1985.0          79
# 1980.0          63
# 1978.0          54
# 1984.0          41
# 1982.0          32
# 1974.0          32
# 1972.0          29
# 2015.0          28
# 1983.0          25
# 1977.0          20
# 2016.0          20
# 1981.0          18
# 1973.0          18
# 1975.0          18
# 1976.0          18
# 2017.0          17
# 1986.0          16
# 1979.0          13
# 1987.0          13
# 2018.0           9
# 2020.0           9
# 2013.0           8
# 2019.0           7
# 2023.0           6
# 2014.0           6
# 1966.0           5
# 1988.0           5
# 1968.0           3
# 1970.0           2
# 1971.0           2
# 2022.0           2
# 2024.0           2
# 2021.0           1
# 2012.0           1
# 2011.0           1
# 1969.0           1
# 1964.0           1
# 1967.0           1
# 2005.0           1
# Name: count, dtype: int64

# %% [markdown]
# It seems like the some of the values in the field `isAdult` are year values and should belong to the `startYear` columns instead.
#
# We closely inspect these rows

# %%
basics_isAdult_filter = basics[~basics['isAdult'].isin([0,1])]
basics_isAdult_filter
# Out:
#               tconst  titleType  \
# 1096866   tt10233364  tvEpisode
# 1506472   tt10970874  tvEpisode
# 1893777   tt11670006  tvEpisode
# 2004597   tt11868642  tvEpisode
# 2158217   tt12149332  tvEpisode
# ...              ...        ...
# 7991997   tt33052217  tvEpisode
# 7992037   tt33052263  tvEpisode
# 8289142    tt3984412  tvEpisode
# 10919145   tt9822816  tvEpisode
# 10958908   tt9909210  tvEpisode
#
#                                                                                                                                           primaryTitle  \
# 1096866                                                                                             Rolling in the Deep Dish\tRolling in the Deep Dish
# 1506472     Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?\tDie Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893777                                                                               ...ein angenehmer Unbequemer...\t...ein angenehmer Unbequemer...
# 2004597                     GGN Heavyweight Championship Lungs With Mike Tyson and Snoop\tGGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2158217                                               Jeopardy! College Championship Semifinal Game 3\tJeopardy! College Championship Semifinal Game 3
# ...                                                                                                                                                ...
# 7991997                                                                                                   Track of the Vampire'\tTrack of the Vampire'
# 7992037                                                                                                             The Clone Master\tThe Clone Master
# 8289142   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race\tI'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 10919145        Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan\tZwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 10958908            Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?\tPolitik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#          originalTitle  isAdult  startYear  endYear          runtimeMinutes  \
# 1096866              0   2019.0        NaN      NaN              Reality-TV
# 1506472              0   2019.0        NaN      NaN               Talk-Show
# 1893777              0   1981.0        NaN      NaN             Documentary
# 2004597              0   2020.0        NaN      NaN               Talk-Show
# 2158217              0   2020.0        NaN      NaN               Game-Show
# ...                ...      ...        ...      ...                     ...
# 7991997              0   1986.0        NaN      NaN  Fantasy,Horror,Mystery
# 7992037              0   1986.0        NaN      NaN  Fantasy,Horror,Mystery
# 8289142              0   2014.0        NaN      NaN    Game-Show,Reality-TV
# 10919145             0   2019.0        NaN      NaN               Talk-Show
# 10958908             0   2005.0        NaN      NaN               Talk-Show
#
#          genres
# 1096866     NaN
# 1506472     NaN
# 1893777     NaN
# 2004597     NaN
# 2158217     NaN
# ...         ...
# 7991997     NaN
# 7992037     NaN
# 8289142     NaN
# 10919145    NaN
# 10958908    NaN
#
# [628 rows x 9 columns]

# %% [markdown]
# Looks like this is the same issue as before, where the `\t` seperators were intepreted as literal string.
#
# We will check if all these rows contain a `\t` character, and if every row with value of `isAdult` not equal to 0 or 1 have missing `startYear` values

# %%
# Check if every row in basics_isAdult_filter contains `\t` in the primaryTitle
all(basics_isAdult_filter['primaryTitle'].str.contains('\t'))
# Out:
# True

# %%
basics_isAdult_filter['originalTitle'].value_counts()
# Out:
# originalTitle
# 0    627
# 1      1
# Name: count, dtype: int64

# %%
basics_isAdult_filter['startYear'].unique()
# Out:
# array([nan])

# %% [markdown]
# We conclude that for every row where `isAdult` is neither 0 nor 1:
#
# - Every value in `primaryTitle` contains '\t', which should be the `Tab` separator
# - Every value in `originalTitle` is either 0 or 1, which should belong in the `isAdult` column
# - Every value in `startYear` is missing, which is currently in the `isAdult` column

# %% [markdown]
# We will fix these rows by:
# - Splitting all titles in `primaryTitle` by the `\t` character into `primaryTitle` and `originalTitle`
# - Moving all current values in `originalTitle`, which are 0 or 1, to the `isAdult` field
# - Moving all current values in `originalTitle` (e.g 1985, 1986) to the `startYear` field

# %%
# pd.set_option('mode.chained_assignment', None)
basics_isAdult_filter['startYear'] = basics_isAdult_filter['isAdult']
basics_isAdult_filter['isAdult'] = basics_isAdult_filter['originalTitle']
basics_isAdult_filter[['primaryTitle', 'originalTitle']] = basics_isAdult_filter['primaryTitle'].str.split('\t', expand=True)
basics_isAdult_filter
# Out:
# <ipython-input-22-2e15d070df65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter['startYear'] = basics_isAdult_filter['isAdult']
# <ipython-input-22-2e15d070df65>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter['isAdult'] = basics_isAdult_filter['originalTitle']
# <ipython-input-22-2e15d070df65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter[['primaryTitle', 'originalTitle']] = basics_isAdult_filter['primaryTitle'].str.split('\t', expand=True)
#               tconst  titleType  \
# 1096866   tt10233364  tvEpisode
# 1506472   tt10970874  tvEpisode
# 1893777   tt11670006  tvEpisode
# 2004597   tt11868642  tvEpisode
# 2158217   tt12149332  tvEpisode
# ...              ...        ...
# 7991997   tt33052217  tvEpisode
# 7992037   tt33052263  tvEpisode
# 8289142    tt3984412  tvEpisode
# 10919145   tt9822816  tvEpisode
# 10958908   tt9909210  tvEpisode
#
#                                                                    primaryTitle  \
# 1096866                                                Rolling in the Deep Dish
# 1506472    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893777                                         ...ein angenehmer Unbequemer...
# 2004597            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2158217                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 7991997                                                   Track of the Vampire'
# 7992037                                                        The Clone Master
# 8289142   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 10919145     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 10958908       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#                                                                   originalTitle  \
# 1096866                                                Rolling in the Deep Dish
# 1506472    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893777                                         ...ein angenehmer Unbequemer...
# 2004597            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2158217                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 7991997                                                   Track of the Vampire'
# 7992037                                                        The Clone Master
# 8289142   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 10919145     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 10958908       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#          isAdult  startYear  endYear          runtimeMinutes genres
# 1096866        0     2019.0      NaN              Reality-TV    NaN
# 1506472        0     2019.0      NaN               Talk-Show    NaN
# 1893777        0     1981.0      NaN             Documentary    NaN
# 2004597        0     2020.0      NaN               Talk-Show    NaN
# 2158217        0     2020.0      NaN               Game-Show    NaN
# ...          ...        ...      ...                     ...    ...
# 7991997        0     1986.0      NaN  Fantasy,Horror,Mystery    NaN
# 7992037        0     1986.0      NaN  Fantasy,Horror,Mystery    NaN
# 8289142        0     2014.0      NaN    Game-Show,Reality-TV    NaN
# 10919145       0     2019.0      NaN               Talk-Show    NaN
# 10958908       0     2005.0      NaN               Talk-Show    NaN
#
# [628 rows x 9 columns]

# %%
# Replace the rows in the original DataFrame
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

basics.loc[basics_isAdult_filter.index] = basics_isAdult_filter
basics.head(3)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#   isAdult  startYear  endYear runtimeMinutes                      genres
# 0     0.0     1894.0      NaN              1           Documentary,Short
# 1     0.0     1892.0      NaN              5             Animation,Short
# 2     0.0     1892.0      NaN              5  Action,Adventure,Animation

# %%
basics['isAdult'] = pd.to_numeric(basics['isAdult'])

# %%
basics.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle             0
# originalTitle            0
# isAdult                  0
# startYear          1413851
# endYear           10835189
# runtimeMinutes     7546155
# genres              485606
# dtype: int64

# %% [markdown]
# There are still missing values in `startYear`, `endYear`, `runtimeMinute`, and `genres`. However, these fields are not mandatory and we can safely ignore these missing values.
#
# Quick look at these rows with missing values to ensure they are good data

# %%
basics[basics.startYear.isna()]
# Out:
#              tconst  titleType                          primaryTitle  \
# 619       tt0000624      short                     The Ugly Duckling
# 65748     tt0067098  tvEpisode                           Willi Forst
# 83793     tt0085677  tvEpisode                          High Country
# 90916     tt0092975  tvEpisode         Erste Liebe und Heiratssachen
# 90962     tt0093025      movie            Tales of the Brothers Quay
# ...             ...        ...                                   ...
# 10962336  tt9916616      short                                Terror
# 10962338  tt9916620      movie                     The Copeland Case
# 10962352  tt9916652      short      Untitled well- being Documentary
# 10962358  tt9916664      short  Untitled Land Army Girls Documentary
# 10962376  tt9916702      short         Loving London: The Playground
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 619                          The Ugly Duckling      0.0        NaN      NaN
# 65748                              Willi Forst      0.0        NaN      NaN
# 83793                             High Country      0.0        NaN      NaN
# 90916            Erste Liebe und Heiratssachen      0.0        NaN      NaN
# 90962           The Films of the Brothers Quay      0.0        NaN      NaN
# ...                                        ...      ...        ...      ...
# 10962336                                Terror      0.0        NaN      NaN
# 10962338                     The Copeland Case      0.0        NaN      NaN
# 10962352      Untitled well- being Documentary      0.0        NaN      NaN
# 10962358  Untitled Land Army Girls Documentary      0.0        NaN      NaN
# 10962376         Loving London: The Playground      0.0        NaN      NaN
#
#          runtimeMinutes                 genres
# 619                 NaN                  Short
# 65748                55                    NaN
# 83793               NaN                  Sport
# 90916               NaN            Documentary
# 90962                78  Animation,Documentary
# ...                 ...                    ...
# 10962336             13            Drama,Short
# 10962338            NaN                  Drama
# 10962352            NaN                  Short
# 10962358            NaN                  Short
# 10962376            NaN            Drama,Short
#
# [1413851 rows x 9 columns]

# %% [markdown]
# Now that all values in `primaryTitle`, `originalTitle`, `isAdult` fields have been reassigned and moved to their corresponding field, we will filter out all adult movies, which have `isAdult` equal to 1

# %%
# Remove all rows with 'isAdult' = 1
basics = basics[basics['isAdult'] == 0]
basics['isAdult'].value_counts()
# Out:
# isAdult
# 0.0    10610432
# Name: count, dtype: int64

# %% [markdown]
# Finally, we reformat the `genres` column by adding a whitespace `\s` after every comma `,`

# %%
basics['genres'] = basics['genres'].str.replace(r',', r', ')
basics['genres'].head(3)
# Out:
# 0              Documentary, Short
# 1                Animation, Short
# 2    Action, Adventure, Animation
# Name: genres, dtype: object

# %% [markdown]
# ### Data Cleaning for `episode` Dataset

# %%
episode.dtypes
# Out:
# tconst            object
# parentTconst      object
# seasonNumber     float64
# episodeNumber    float64
# dtype: object

# %%
episode.isna().sum()
# Out:
# tconst                 0
# parentTconst           0
# seasonNumber     1702596
# episodeNumber    1702596
# dtype: int64

# %% [markdown]
# Remove all rows with missing `seasonNumber` or `episodeNumber`

# %%
episode.dropna(inplace=True)
episode.isna().sum()
# Out:
# tconst           0
# parentTconst     0
# seasonNumber     0
# episodeNumber    0
# dtype: int64

# %%
episode['seasonNumber'] = episode['seasonNumber'].astype(int)
episode['episodeNumber'] = episode['episodeNumber'].astype(int)
episode.dtypes
# Out:
# tconst           object
# parentTconst     object
# seasonNumber      int64
# episodeNumber     int64
# dtype: object

# %% [markdown]
# ### Data Cleaning for `ratings` Dataset

# %%
ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %% [markdown]
# ## Data Merging for Episodes
# Join all 3 tables on `basics.tconst = episode.tconst = ratings.tconst`

# %%
# prompt: inner join episode['tconst'] on ratings['tconst'] and basics['tconst'] into 1 table

# Merge ratings and episode on 'tconst'
ratings_episode = pd.merge(ratings, episode, on='tconst', how='inner')

# Merge the result with basics on 'tconst'
episode_all = pd.merge(ratings_episode, basics, on='tconst', how='inner')

# %%
print(episode_all['tconst'].is_unique)
print(len(episode_all))
episode_all.head(5)
# Out:
# True
# 717562
#       tconst  averageRating  numVotes parentTconst  seasonNumber  \
# 0  tt0041951            7.6        92    tt0041038             1
# 1  tt0042816            7.6        12    tt0989125             1
# 2  tt0044093            4.6        19    tt0959862             1
# 3  tt0045960            6.9       195    tt0044284             2
# 4  tt0046855            5.9       166    tt0046643             1
#
#    episodeNumber  titleType          primaryTitle         originalTitle  \
# 0              9  tvEpisode        The Tenderfeet        The Tenderfeet
# 1             17  tvEpisode               Othello               Othello
# 2              6  tvEpisode  The Three Musketeers  The Three Musketeers
# 3              3  tvEpisode             King Lear             King Lear
# 4              4  tvEpisode     A Christmas Carol     A Christmas Carol
#
#    isAdult  startYear  endYear runtimeMinutes                    genres
# 0      0.0     1949.0      NaN             30                   Western
# 1      0.0     1950.0      NaN            135                     Drama
# 2      0.0     1950.0      NaN             60                     Drama
# 3      0.0     1953.0      NaN             75     Drama, History, Music
# 4      0.0     1954.0      NaN             60  Adventure, Drama, Family

# %% [markdown]
# Checking if all `parentTconst` are in `basics.tconst` and `ratings.tconst`

# %%
# Check if all episode_all['parentTconst'] is in both basics['tconst'] and ratings['tconst']

# Check if all episode_all['parentTconst'] are in basics['tconst']
tmp = all(episode_all['parentTconst'].isin(basics['tconst']))
print("All 'parentTconst' in basics['tconst']: ", tmp)

# Check if all episode_all['parentTconst'] are in ratings['tconst']
tmp = all(episode_all['parentTconst'].isin(ratings['tconst']))
print("All 'parentTconst' in ratings['tconst']: ", tmp)
# Out:
# All 'parentTconst' in basics['tconst']:  True
# All 'parentTconst' in ratings['tconst']:  False

# %%
# Only keep episodes with the whole series ratings
# Filter all_data to keep only rows where 'parentTconst' is in ratings['tconst']

episode_all = episode_all[episode_all['parentTconst'].isin(ratings['tconst'])]
print(len(episode_all))
episode_all.head()
# Out:
# 716664
#       tconst  averageRating  numVotes parentTconst  seasonNumber  \
# 0  tt0041951            7.6        92    tt0041038             1
# 1  tt0042816            7.6        12    tt0989125             1
# 2  tt0044093            4.6        19    tt0959862             1
# 3  tt0045960            6.9       195    tt0044284             2
# 4  tt0046855            5.9       166    tt0046643             1
#
#    episodeNumber  titleType          primaryTitle         originalTitle  \
# 0              9  tvEpisode        The Tenderfeet        The Tenderfeet
# 1             17  tvEpisode               Othello               Othello
# 2              6  tvEpisode  The Three Musketeers  The Three Musketeers
# 3              3  tvEpisode             King Lear             King Lear
# 4              4  tvEpisode     A Christmas Carol     A Christmas Carol
#
#    isAdult  startYear  endYear runtimeMinutes                    genres
# 0      0.0     1949.0      NaN             30                   Western
# 1      0.0     1950.0      NaN            135                     Drama
# 2      0.0     1950.0      NaN             60                     Drama
# 3      0.0     1953.0      NaN             75     Drama, History, Music
# 4      0.0     1954.0      NaN             60  Adventure, Drama, Family

# %% [markdown]
# Recheck

# %%
# Double check that all `episode_all['parentTconst']` is in both basics['tconst'] and ratings ['tconst']
tmp = all(episode_all['parentTconst'].isin(basics['tconst']))
print("All episode['parentTconst'] in basics['tconst']: ", tmp)

# Check if all episode['parentTconst'] are in ratings['tconst']
tmp = all(episode_all['parentTconst'].isin(ratings['tconst']))
print("All episode['parentTconst'] in ratings['tconst']: ", tmp)
# Out:
# All episode['parentTconst'] in basics['tconst']:  True
# All episode['parentTconst'] in ratings['tconst']:  True

# %% [markdown]
# Add a new column to `episode_all` containing the episode no., szn no., and primary title

# %%
episode_all['eSTitle'] = episode_all['seasonNumber'].astype(str) + '.' + episode_all['episodeNumber'].astype(str) + ' - ' + episode_all['primaryTitle']
episode_all.head()
# Out:
#       tconst  averageRating  numVotes parentTconst  seasonNumber  \
# 0  tt0041951            7.6        92    tt0041038             1
# 1  tt0042816            7.6        12    tt0989125             1
# 2  tt0044093            4.6        19    tt0959862             1
# 3  tt0045960            6.9       195    tt0044284             2
# 4  tt0046855            5.9       166    tt0046643             1
#
#    episodeNumber  titleType          primaryTitle         originalTitle  \
# 0              9  tvEpisode        The Tenderfeet        The Tenderfeet
# 1             17  tvEpisode               Othello               Othello
# 2              6  tvEpisode  The Three Musketeers  The Three Musketeers
# 3              3  tvEpisode             King Lear             King Lear
# 4              4  tvEpisode     A Christmas Carol     A Christmas Carol
#
#    isAdult  startYear  endYear runtimeMinutes                    genres  \
# 0      0.0     1949.0      NaN             30                   Western
# 1      0.0     1950.0      NaN            135                     Drama
# 2      0.0     1950.0      NaN             60                     Drama
# 3      0.0     1953.0      NaN             75     Drama, History, Music
# 4      0.0     1954.0      NaN             60  Adventure, Drama, Family
#
#                       eSTitle
# 0        1.9 - The Tenderfeet
# 1              1.17 - Othello
# 2  1.6 - The Three Musketeers
# 3             2.3 - King Lear
# 4     1.4 - A Christmas Carol

# %% [markdown]
# ## Data Merging for Series

# %%
# Get distinct values in episode_all['parentTconst']
distinct_parentTconst = episode_all['parentTconst'].unique()

# Filter basics and ratings based on distinct_parentTconst
basics_parentTconst = basics[basics['tconst'].isin(distinct_parentTconst)]
ratings_parentTconst = ratings[ratings['tconst'].isin(distinct_parentTconst)]

# Inner join filtered_basics and filtered_ratings on 'tconst'
series_all = pd.merge(basics_parentTconst, ratings_parentTconst, on='tconst', how='inner')
series_all
# Out:
#           tconst titleType                        primaryTitle  \
# 0      tt0039123  tvSeries                       Kraft Theatre
# 1      tt0039125  tvSeries                   Public Prosecutor
# 2      tt0040021  tvSeries                      Actor's Studio
# 3      tt0040041  tvSeries               The Milton Berle Show
# 4      tt0040048  tvSeries       Perry Como's Kraft Music Hall
# ...          ...       ...                                 ...
# 37041  tt9914546  tvSeries                   Moja Generacija Z
# 37042  tt9914700  tvSeries  Aunty Donna: Best Content Ever!!1!
# 37043  tt9915144  tvSeries                          Never Ever
# 37044  tt9916128  tvSeries                   Salt City (India)
# 37045  tt9916380  tvSeries                 Meie aasta Aafrikas
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                       Kraft Television Theatre      0.0     1947.0   1958.0
# 1                              Public Prosecutor      0.0     1947.0   1951.0
# 2                                 Actor's Studio      0.0     1948.0   1950.0
# 3      Texaco Star Theatre Starring Milton Berle      0.0     1948.0   1956.0
# 4                            The Perry Como Show      0.0     1948.0   1967.0
# ...                                          ...      ...        ...      ...
# 37041                          Moja Generacija Z      0.0     2019.0      NaN
# 37042         Aunty Donna: Best Content Ever!!1!      0.0     2017.0   2017.0
# 37043                                 Never Ever      0.0     2018.0      NaN
# 37044                          Salt City (India)      0.0     2022.0      NaN
# 37045                        Meie aasta Aafrikas      0.0     2019.0      NaN
#
#       runtimeMinutes                           genres  averageRating  numVotes
# 0                 60                            Drama            8.0       224
# 1                 20            Crime, Drama, Mystery            5.9        35
# 2                 30                            Drama            6.9        93
# 3                 60                   Comedy, Family            7.6       167
# 4                 60                            Music            7.6       122
# ...              ...                              ...            ...       ...
# 37041             30            Comedy, Drama, Family            4.2       196
# 37042              5                           Comedy            8.2        27
# 37043            NaN  Biography, Documentary, History            9.0        91
# 37044            NaN                            Drama            6.0       129
# 37045             43        Adventure, Comedy, Family            8.2       120
#
# [37046 rows x 11 columns]

# %%
# Check that the sets of value in episode_all['parentTconst'] and data_parentTconst['tconst'] are the same
set1 = set(episode_all['parentTconst'])
set2 = set(series_all['tconst'])

print(set1 == set2)
# Out:
# True

# %% [markdown]
# # Export data

# %%
episode_all.to_csv('episode_all.csv', index=False)
series_all.to_csv('series_all.csv', index=False)
